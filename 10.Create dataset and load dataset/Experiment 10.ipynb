# %% [markdown]
# <a href="https://colab.research.google.com/github/Kovidapunj/Exploratory-data-analysis-using-python/blob/main/Copy_of_Experiment_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 10
# ## title- create dataset and load dataset
# ## name - Kovida Punj
# ## prn - 25070123063
# ## batch - E&TC A3
# ## date - 20/02/2026

# %%
import pandas as pd
data = {
     "Roll_no":[101, 102, 103, 104, 105],
     "Gender":["Female","Male","Female","Male","Female"],
     "Department":["CSE","IT","E&TC","Mechanical","CSE"],
     "CGPA":[8.2,7.5,9.1,6.8,8.7]
}
df = pd.DataFrame(data)
df.to_csv("students.csv",index=False)
df
# Out:
#    Roll_no  Gender  Department  CGPA
# 0      101  Female         CSE   8.2
# 1      102    Male          IT   7.5
# 2      103  Female        E&TC   9.1
# 3      104    Male  Mechanical   6.8
# 4      105  Female         CSE   8.7

# %%
df.shape
# Out:
# (5, 4)

# %%
#Access information of Column department
#Access information of PRN 103
#Find out data type of each column
#Perform mean,median,mode operation
#Insert a new column Grade
#Delete gender column
#CGPA of topper
#CGPA of PRN 105

# %%
#Access information of Column department
df["Department"]
# Out:
# 0           CSE
# 1            IT
# 2          E&TC
# 3    Mechanical
# 4           CSE
# Name: Department, dtype: object

# %%
#Access information of PRN 103
df.loc[2]
# Out:
# Roll_no          103
# Gender        Female
# Department      E&TC
# CGPA             9.1
# Name: 2, dtype: object

# %%
#Find out data type of each column
df.dtypes
# Out:
# Roll_no         int64
# Gender         object
# Department     object
# CGPA          float64
# dtype: object

# %%
#Perform mean,median,mode operation
mode1 = df["Department"].mode()
mode1
# Out:
# 0    CSE
# Name: Department, dtype: object

# %%
#Perform mean,median,mode operation
mean1 = df["CGPA"].mean()
mean1
# Out:
# np.float64(8.059999999999999)

# %%
#Perform mean,median,mode operation
median1 = df["CGPA"].median()
median1
# Out:
# 8.2

# %%
#Insert a new column Grade
df["Grade"] = ["A","B","A","C","A"]
df
# Out:
#    Roll_no  Gender  Department  CGPA Grade
# 0      101  Female         CSE   8.2     A
# 1      102    Male          IT   7.5     B
# 2      103  Female        E&TC   9.1     A
# 3      104    Male  Mechanical   6.8     C
# 4      105  Female         CSE   8.7     A

# %%
#Delete gender column
df.drop("Grade",axis=1, inplace=True)
df
# Out:
#    Roll_no  Gender  Department  CGPA
# 0      101  Female         CSE   8.2
# 1      102    Male          IT   7.5
# 2      103  Female        E&TC   9.1
# 3      104    Male  Mechanical   6.8
# 4      105  Female         CSE   8.7

# %%
#CGPA of topper
max1 = df["CGPA"].max()
max1
# Out:
# 9.1

# %%
#CGPA of PRN 105
df["CGPA"]
# Out:
# 0    8.2
# 1    7.5
# 2    9.1
# 3    6.8
# 4    8.7
# Name: CGPA, dtype: float64

# %%
#upload the dataset
import pandas as pd
import numpy as np
df=pd.read_csv('/content/Cars93.csv')
df
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25                 NaN
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# 1          200           5            30.0          15.0
# 2          172           5            28.0          14.0
# 3          172           6            31.0          17.0
# 4          208           4            27.0          13.0
# ..         ...         ...             ...           ...
# 88         109           7            34.0           NaN
# 89         134           5            31.5          14.0
# 90         178           4            26.0          15.0
# 91         114           5            29.5          14.0
# 92         168           5            30.0          15.0
#
# [93 rows x 10 columns]

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25                 NaN
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
df.tail()
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 88         109           7            34.0           NaN
# 89         134           5            31.5          14.0
# 90         178           4            26.0          15.0
# 91         114           5            29.5          14.0
# 92         168           5            30.0          15.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         59 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 7.4+ KB

# %%
df.describe()
# Out:
#            Price   MPG.city  Horsepower  Passengers  Rear.seat.room  \
# count  93.000000  93.000000   93.000000   93.000000       91.000000
# mean   19.509677  22.365591  143.827957    5.086022       27.829670
# std     9.659430   5.619812   52.374410    1.038979        2.989072
# min     7.400000  15.000000   55.000000    2.000000       19.000000
# 25%    12.200000  18.000000  103.000000    4.000000       26.000000
# 50%    17.700000  21.000000  140.000000    5.000000       27.500000
# 75%    23.300000  25.000000  170.000000    6.000000       30.000000
# max    61.900000  46.000000  300.000000    8.000000       36.000000
#
#        Luggage.room
# count     82.000000
# mean      13.890244
# std        2.997967
# min        6.000000
# 25%       12.000000
# 50%       14.000000
# 75%       15.000000
# max       22.000000

# %%
df.size
# Out:
# 930
