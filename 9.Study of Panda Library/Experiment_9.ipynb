# %% [markdown]
# <a href="https://colab.research.google.com/github/Kovidapunj/Exploratory-data-analysis-using-python/blob/main/Experiment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #experiment 9
# ## title - Study of Pandas Library
# ## name - Kovida Punj
# ## PRN - 25070123063
# ## Batch - E&TC A3
# ## date - 18/02/2026

# %%
#structured data
# EDA
# data cleaning

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#create DataFrame
data = {
    "Name":["A","B","C"],
    "Marks":[85,90,78]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
df.head()
df.tail()
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
# find the structure of the Dataframe
df.shape
(3,2)
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
#display column names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check Data Types of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#access individual column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
#Access Specefic Row
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
#Add a New Column
'''If marks 80-90- First class
If marks > 90 - Distinction
If marks > 80- second class'''
df["Grade"]= ["first Class","Distinction","second class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     81   first Class
# 1    B     90   Distinction
# 2    C     78  second class

# %%
#update data in DataFrame
#Change marks of student A to 88
df.loc[0,"Marks"] = 88
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %%
#Delete a Column
df.drop("Grade",axis=1, inplace=True)
df
# Out:
#   Name  Marks
# 0    A     81
# 1    B     90
# 2    C     78

# %%
#perform Basic statistical analysis
mean1 = df["Marks"].mean()
mean1
# Out:
# np.float64(83.0)

# %%
mode1 = df["Marks"].mode()
mode1
# Out:
# 0    78
# 1    81
# 2    90
# Name: Marks, dtype: int64

# %%
min1 = df["Name"].min()
min1
# Out:
# 'A'

# %%
max1 = df["Marks"].max()
max1
# Out:
# 90

# %%
#Apply Condition (filtering)
#Display students scoring more than 80

# %%
df[df["Marks"] > 80]
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame({'C1':[11,21,np.nan],'C2':[15,np.nan,np.nan],'C3':[10,20,30]})
df1
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
# 1  21.0   NaN  20
# 2   NaN   NaN  30

# %%
df1.isna () #BOOLEAN function, conditional statement
# Out:
#       C1     C2     C3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df1.notna ()
# Out:
#       C1     C2    C3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
df1.dropna () #NaN Rows are dropped
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
