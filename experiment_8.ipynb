# %% [markdown]
# <a href="https://colab.research.google.com/github/Kovidapunj/Exploratory-data-analysis-using-python/blob/main/experiment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 8
# ## Title - tool for EDA - study of Numpy library
# ## Name - Kovida Punj
# ## PRN - 25070123063
# ## batch - E&TC A3
# ## date - 18/02/2026

# %%
# faster than lists
# used for numerical computation
# base for pandas

# %%
# declaration of Numpy
import numpy as np

a = np.array([10,20,30,40])
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [4 5 6]]

# %%
#dimension of array
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
print(a.shape)
print(b.shape)
# Out:
# (4,)
# (2, 3)

# %%
print(a.dtype)
# Out:
# int64

# %%
#In built functions using Numpy
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,10,2) #like range function
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
print( b * 2)
print(a + 5)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]
# [15 25 35 45]

# %%
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %%
np.mean(b)
# Out:
# np.float64(3.5)

# %%
np.median(b)
# Out:
# np.float64(3.5)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.sum(a)
# Out:
# np.int64(100)
